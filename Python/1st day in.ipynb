# %%
print ("Eh we all start somewhere")
# Out:
# Eh we all start somewhere

# %% [markdown]
# #### Thankyou to Mr. Rossum for this language and to the people of year 1991 for not killing his work.

# %% [markdown]
# # Basics

# %% [markdown]
# - python is both compiled and interpreted, firts compiles into bytecode and bytecode is what is interpreted by Python virtual machine
#
# - bytecode is low level instruction set that is for every python VM
#
# - dis module can be used to see bytecode
#
# - .py /.ipynb >compiled >bytecode.pyc >PVM >CPU
#
# - .pyc and pycache are created usually when modules are imported
#
# - python does not store values inside variables , variabes are just name of an object that has the value so object is created
#
# - to know how or show how the id function is used. *print(id(variablename))*
#
# - everything is an object in python even class , types **everything **
#
# - Objects have 3 things - Id, type, value. adding a new value to an object will not change the id of it be it a variable or class
#
# - Immutable objects : cannot change like integers inside an object int =
# float
# bool
# str
# tuple
# frozenset
# bytes
#
# - Mutable objects : can change after creation like =
# list
# dict
# set
# bytearray
#
# - python will store commonly created object integers -5 to 256 in memory as cache
#    simple way of confusing the *is* and *==*
#    *is* checks for identity and *==* checks for value
#
#    both come true for something like 100 but not for 1000
#    for 1000 is comes false cause its not cached
#
# - while in a class unless defined *==* will compare identity only but if defined that it has to compare values of object it will do that
# - *is* will be used for None , true , false , checking ID otherwise can and will cause errors
# - in the case of none it works because there is only 1 none object in the cache ever
# -
