# %%
print ("Eh we all start somewhere")
# Out:
# Eh we all start somewhere

# %% [markdown]
# #### Thankyou to Mr. Rossum for this language and to the people of year 1991 for not killing his work.

# %% [markdown]
# # Basics

# %% [markdown]
# - python is both compiled and interpreted, firts compiles into bytecode and bytecode is what is interpreted by Python virtual machine
#
# - bytecode is low level instruction set that is for every python VM
#
# - dis module can be used to see bytecode
#
# - .py /.ipynb >compiled >bytecode.pyc >PVM >CPU
#
# - .pyc and pycache are created usually when modules are imported
#
# - python does not store values inside variables , variabes are just name of an object that has the value so object is created
#
# - to know how or show how the id function is used. *print(id(variablename))*
#
# - everything is an object in python even class , types **everything **
#
# - Objects have 3 things - Id, type, value. adding a new value to an object will not change the id of it be it a variable or class
#
# - Immutable objects : cannot change like integers inside an object int =
# float
# bool
# str
# tuple
# frozenset
# bytes
#
# - Mutable objects : can change after creation like =
# list
# dict
# set
# bytearray
#
# - python will store commonly created object integers -5 to 256 in memory as cache
#    simple way of confusing the *is* and *==*
#    *is* checks for identity and *==* checks for value
#
#    both come true for something like 100 but not for 1000
#    for 1000 is comes false cause its not cached
#
# - while in a class unless defined *==* will compare identity only but if defined that it has to compare values of object it will do that
#
# - *is* will be used for None , true , false , checking ID otherwise can and will cause errors
#
# - in the case of *isnone* it works because there is only 1 none object in the cache ever
#
# - in functions the default argument is only evaluated once so consecutive calls of a function will not mean *def* is being re evaluated each time so when we use an immutable as parameter that will not be modified each time and weget same result each time but if something mutable is used the last addition/ change will be recorded and the mutable will be changed to that
#
# - so while making functions and passing default parameters lets assume some object has to be blank at the start , the *isnone* will be used for it so everytime a fresh list is created , if we pass a clean list[] it will append as lists are mutable
#
# - the semicolon is not needed to end a stateent or  line of code, it ends when the line ends but can be used to write multiple statements in one line

# %% [markdown]
# #### The star loop, where it all began in my head

# %%
def star(val):

    stars = []
    
    for i in range(val):

        stars.append("*")

        print(stars)
        
    while len(stars) > 0:

        stars.pop()

        print(stars)

star(5)
# Out:
# ['*']
# ['*', '*']
# ['*', '*', '*']
# ['*', '*', '*', '*']
# ['*', '*', '*', '*', '*']
# ['*', '*', '*', '*']
# ['*', '*', '*']
# ['*', '*']
# ['*']
# []

# %%
# !python --version
import sys
print(sys.version)
x= sys.version_info
print(x , "The version in python",3, "is the latest version")
# Out:
# Python 3.10.17
# 3.10.17 | packaged by conda-forge | (main, Apr 10 2025, 22:06:35) [MSC v.1943 64 bit (AMD64)]
# sys.version_info(major=3, minor=10, micro=17, releaselevel='final', serial=0) The version in python 3 is the latest version

# %% [markdown]
# # Basics 2

# %% [markdown]
# - print() function needs quotes around text but not around numbers to print, simple arithematic operators can also be used inside print
#
# - data type can be accessed by *type()*
#
# - copy vs deepcopy: a normal copy only gets the outermost or only the cabinet and not the files but very logically whats inside also comes but not as a consequence of the copy on the other hand a deepcopy gets the files of the cabinet as well, the copy keeps the nested objects shared and the outer object is new so deep copy better
#
# - dictionaries use hashing and python in itself uses hashing a disctionary value are stored at different indexes after hashing , thats why its  fast and searching is not O(n) and that means lookup is fast so its O(1) also for a mutable object hashing wont be possible as changing the values would change the hash
# -
